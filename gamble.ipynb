# %%
# importing the require data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# reading python file 
data = pd.read_csv('odd.csv')
data.head()
# Out:
#    Unnamed: 0                                            fixture  \
# 0           0  {'id': 945470, 'status': {'long': 'First Half'...
# 1           1  {'id': 945472, 'status': {'long': 'First Half'...
# 2           2  {'id': 945475, 'status': {'long': 'Second Half...
# 3           3  {'id': 945477, 'status': {'long': 'First Half'...
# 4           4  {'id': 838976, 'status': {'long': 'Second Half...
#
#                         league  \
# 0  {'id': 390, 'season': 2022}
# 1  {'id': 390, 'season': 2022}
# 2  {'id': 390, 'season': 2022}
# 3  {'id': 390, 'season': 2022}
# 4   {'id': 72, 'season': 2022}
#
#                                                teams  \
# 0  {'home': {'id': 4568, 'goals': 0}, 'away': {'i...
# 1  {'home': {'id': 4576, 'goals': 0}, 'away': {'i...
# 2  {'home': {'id': 4568, 'goals': 1}, 'away': {'i...
# 3  {'home': {'id': 4578, 'goals': 0}, 'away': {'i...
# 4  {'home': {'id': 755, 'goals': 0}, 'away': {'id...
#
# ...
